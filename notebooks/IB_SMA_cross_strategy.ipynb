# %% [markdown]
# # SMA Strategy
#
# References:
#  - https://algotrading101.com/learn/interactive-brokers-python-api-native-guide/

# %%
app.disconnect()

# %%
from ibapi.client import EClient
from ibapi.wrapper import EWrapper  
from ibapi.contract import Contract

import threading
import time

class IBapi(EWrapper, EClient):
    def __init__(self):
        EClient.__init__(self, self)
        self.data = []

    def tickPrice(self, reqId, tickType, price, attrib):
        if tickType == 2 and reqId == 1:
            print(tickType, ': The current ask price is: ', price)
    
    def historicalData(self, reqId, bar):
        #print(f'Time: {bar.date} Close: {bar.close}')
        self.data.append([bar.date, bar.open, bar.high, bar.low, bar.close])
        
def run_loop():
    app.run()

app = IBapi()
app.connect('host.docker.internal', 7496, 3)

api_thread = threading.Thread(target=run_loop, daemon=True)
api_thread.start()
time.sleep(0.5)
# Out:
# ERROR -1 2104 Market data farm connection is OK:hfarm
# ERROR -1 2104 Market data farm connection is OK:cafarm
# ERROR -1 2104 Market data farm connection is OK:eufarmnj
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:uscrypto
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:afarm
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:eufarm
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2106 HMDS data farm connection is OK:ushmds.nj
# ERROR -1 2106 HMDS data farm connection is OK:cashhmds
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefeu

# %%
apple_contract = Contract()
apple_contract.symbol = 'AAPL'
apple_contract.secType = 'STK'
apple_contract.exchange = 'SMART'
apple_contract.currency = 'USD'

#Request Market Data
app.reqMktData(1, apple_contract, '', False, False, [])
# Out:
# 2 : The current ask price is:  164.41
# 2 : The current ask price is:  164.4
# 2 : The current ask price is:  164.41
# 2 : The current ask price is:  164.4
# 2 : The current ask price is:  164.41
# 2 : The current ask price is:  164.4
# 2 : The current ask price is:  164.41
# 2 : The current ask price is:  164.4
# 2 : The current ask price is:  164.41
# 2 : The current ask price is:  164.4
# 2 : The current ask price is:  164.39
# 2 : The current ask price is:  164.4
# 2 : The current ask price is:  164.39
# 2 : The current ask price is:  164.4
# 2 : The current ask price is:  164.39
# 2 : The current ask price is:  164.4
# 2 : The current ask price is:  164.39
# 2 : The current ask price is:  164.4
# 2 : The current ask price is:  164.41
# 2 : The current ask price is:  164.4
# 2 : The current ask price is:  164.41
# 2 : The current ask price is:  164.4
# 2 : The current ask price is:  164.39
# 2 : The current ask price is:  164.4
# 2 : The current ask price is:  164.39
# 2 : The current ask price is:  164.4
# 2 : The current ask price is:  164.39
# 2 : The current ask price is:  164.4
# 2 : The current ask price is:  164.41
# 2 : The current ask price is:  164.4
# 2 : The current ask price is:  164.38
# 2 : The current ask price is:  164.39
# 2 : The current ask price is:  164.38
# 2 : The current ask price is:  164.39
# 2 : The current ask price is:  164.4
# 2 : The current ask price is:  164.41
# 2 : The current ask price is:  164.4
# 2 : The current ask price is:  164.41
# 2 : The current ask price is:  164.4
# 2 : The current ask price is:  164.41
# 2 : The current ask price is:  164.4
# 2 : The current ask price is:  164.41
# 2 : The current ask price is:  164.4
# 2 : The current ask price is:  164.39
# 2 : The current ask price is:  164.4
# 2 : The current ask price is:  164.39
# 2 : The current ask price is:  164.38
# 2 : The current ask price is:  164.39
# 2 : The current ask price is:  164.38
# 2 : The current ask price is:  164.39
# 2 : The current ask price is:  164.38
# 2 : The current ask price is:  164.39
# 2 : The current ask price is:  164.38
# 2 : The current ask price is:  164.39
# 2 : The current ask price is:  164.38
# 2 : The current ask price is:  164.37
# 2 : The current ask price is:  164.36
# 2 : The current ask price is:  164.37
# 2 : The current ask price is:  164.39
# 2 : The current ask price is:  164.41
# 2 : The current ask price is:  164.42
# 2 : The current ask price is:  164.41
# 2 : The current ask price is:  164.42
# 2 : The current ask price is:  164.41
# 2 : The current ask price is:  164.42
# 2 : The current ask price is:  164.41
# 2 : The current ask price is:  164.4
# 2 : The current ask price is:  164.41
# 2 : The current ask price is:  164.4
# 2 : The current ask price is:  164.39
# 2 : The current ask price is:  164.4
# 2 : The current ask price is:  -1.0
# 2 : The current ask price is:  164.41
# 2 : The current ask price is:  164.4
# 2 : The current ask price is:  164.41
# 2 : The current ask price is:  164.4
# 2 : The current ask price is:  164.41
# 2 : The current ask price is:  164.4
# 2 : The current ask price is:  164.41
# 2 : The current ask price is:  164.4
# 2 : The current ask price is:  164.41
# 2 : The current ask price is:  164.4
# 2 : The current ask price is:  164.41
# 2 : The current ask price is:  164.4
# 2 : The current ask price is:  164.41
# 2 : The current ask price is:  164.43
# 2 : The current ask price is:  164.42
# 2 : The current ask price is:  164.41
# 2 : The current ask price is:  164.42
# 2 : The current ask price is:  164.41
# 2 : The current ask price is:  164.42
# 2 : The current ask price is:  164.43
# 2 : The current ask price is:  164.44
# 2 : The current ask price is:  164.43
# 2 : The current ask price is:  164.44
# 2 : The current ask price is:  164.43
# 2 : The current ask price is:  164.42
# 2 : The current ask price is:  164.43
# 2 : The current ask price is:  164.42
# 2 : The current ask price is:  164.43
# 2 : The current ask price is:  164.44
# 2 : The current ask price is:  164.45
# 2 : The current ask price is:  164.46
# 2 : The current ask price is:  164.45
# 2 : The current ask price is:  164.44
# 2 : The current ask price is:  164.39
# 2 : The current ask price is:  164.38
# 2 : The current ask price is:  164.39
# 2 : The current ask price is:  164.38
# 2 : The current ask price is:  164.37
# 2 : The current ask price is:  164.36
# 2 : The current ask price is:  164.37
# 2 : The current ask price is:  164.36
# 2 : The current ask price is:  164.37
# 2 : The current ask price is:  164.36
# 2 : The current ask price is:  164.37
# 2 : The current ask price is:  164.35
# 2 : The current ask price is:  164.34
# 2 : The current ask price is:  164.33
# 2 : The current ask price is:  164.32
# 2 : The current ask price is:  164.31
# 2 : The current ask price is:  164.32
# 2 : The current ask price is:  164.31
# 2 : The current ask price is:  164.3
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.3
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.3
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.3
# 2 : The current ask price is:  164.31
# 2 : The current ask price is:  164.3
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.3
# 2 : The current ask price is:  164.31
# 2 : The current ask price is:  164.3
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.3
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.3
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.26
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.26
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.26
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.3
# 2 : The current ask price is:  164.31
# 2 : The current ask price is:  164.3
# 2 : The current ask price is:  164.31
# 2 : The current ask price is:  164.3
# 2 : The current ask price is:  164.31
# 2 : The current ask price is:  164.3
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.31
# 2 : The current ask price is:  164.32
# 2 : The current ask price is:  164.31
# 2 : The current ask price is:  164.3
# 2 : The current ask price is:  164.31
# 2 : The current ask price is:  164.3
# 2 : The current ask price is:  164.31
# 2 : The current ask price is:  164.3
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.26
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.26
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.26
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.26
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.26
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.26
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.26
# 2 : The current ask price is:  164.27
# ERROR -1 2103 Market data farm connection is broken:jfarm
# ERROR -1 2103 Market data farm connection is broken:jfarm
# 2 : The current ask price is:  164.26
# ERROR -1 2104 Market data farm connection is OK:jfarm
# ERROR -1 2104 Market data farm connection is OK:jfarm
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.26
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.26
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.26
# 2 : The current ask price is:  164.25
# 2 : The current ask price is:  164.26
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.26
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.3
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.3
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.26
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.3
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.3
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.3
# 2 : The current ask price is:  164.31
# 2 : The current ask price is:  164.3
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.3
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.3
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.3
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.3
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.3
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.26
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.26
# 2 : The current ask price is:  164.25
# 2 : The current ask price is:  164.26
# 2 : The current ask price is:  164.25
# 2 : The current ask price is:  164.26
# 2 : The current ask price is:  -1.0
# 2 : The current ask price is:  164.26
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.28
# 2 : The current ask price is:  164.27
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.3
# 2 : The current ask price is:  164.29
# 2 : The current ask price is:  164.3
# 2 : The current ask price is:  164.31
# 2 : The current ask price is:  164.3
# 2 : The current ask price is:  164.31
# 2 : The current ask price is:  164.32
# 2 : The current ask price is:  164.31
# 2 : The current ask price is:  164.34
# 2 : The current ask price is:  164.33
# 2 : The current ask price is:  164.34
# 2 : The current ask price is:  164.36
# 2 : The current ask price is:  164.37
# 2 : The current ask price is:  164.38
# 2 : The current ask price is:  164.37
# 2 : The current ask price is:  164.38
# 2 : The current ask price is:  164.37
# 2 : The current ask price is:  164.38
# 2 : The current ask price is:  164.37
# 2 : The current ask price is:  -1.0
# 2 : The current ask price is:  164.38
# 2 : The current ask price is:  164.37
# 2 : The current ask price is:  164.38
# 2 : The current ask price is:  164.37
# 2 : The current ask price is:  164.38
# 2 : The current ask price is:  164.39
# 2 : The current ask price is:  164.38
# 2 : The current ask price is:  164.37
# 2 : The current ask price is:  164.38
# 2 : The current ask price is:  164.39
# 2 : The current ask price is:  164.4
# 2 : The current ask price is:  164.39
# 2 : The current ask price is:  164.4
# 2 : The current ask price is:  164.41
# 2 : The current ask price is:  164.42
# 2 : The current ask price is:  164.43
# 2 : The current ask price is:  164.42
# 2 : The current ask price is:  164.43
# 2 : The current ask price is:  164.42
# 2 : The current ask price is:  164.43
# 2 : The current ask price is:  164.42
# 2 : The current ask price is:  164.43
# 2 : The current ask price is:  164.44
# 2 : The current ask price is:  164.45
# 2 : The current ask price is:  164.44
# 2 : The current ask price is:  164.45
# 2 : The current ask price is:  164.44
# 2 : The current ask price is:  164.45
# 2 : The current ask price is:  164.47
# 2 : The current ask price is:  164.48
# 2 : The current ask price is:  164.49
# 2 : The current ask price is:  164.5
# 2 : The current ask price is:  164.53
# 2 : The current ask price is:  164.54
# 2 : The current ask price is:  164.53
# 2 : The current ask price is:  164.54
# 2 : The current ask price is:  164.53
# 2 : The current ask price is:  164.54
# 2 : The current ask price is:  164.53
# 2 : The current ask price is:  164.54
# 2 : The current ask price is:  164.55
# 2 : The current ask price is:  164.54
# 2 : The current ask price is:  164.55
# 2 : The current ask price is:  164.54
# 2 : The current ask price is:  164.53
# 2 : The current ask price is:  164.54
# 2 : The current ask price is:  164.51
# 2 : The current ask price is:  164.53
# 2 : The current ask price is:  164.52
# 2 : The current ask price is:  164.53
# 2 : The current ask price is:  164.52
# 2 : The current ask price is:  164.53
# 2 : The current ask price is:  164.52
# 2 : The current ask price is:  164.51
# 2 : The current ask price is:  164.5
# 2 : The current ask price is:  164.51
# 2 : The current ask price is:  164.53
# 2 : The current ask price is:  164.52
# 2 : The current ask price is:  164.53
# 2 : The current ask price is:  164.52
# 2 : The current ask price is:  164.51
# 2 : The current ask price is:  164.52
# 2 : The current ask price is:  164.53
# 2 : The current ask price is:  164.54
# 2 : The current ask price is:  164.55
# 2 : The current ask price is:  164.54
# 2 : The current ask price is:  164.53
# 2 : The current ask price is:  164.52
# 2 : The current ask price is:  164.53
# 2 : The current ask price is:  164.55
# 2 : The current ask price is:  164.54
# 2 : The current ask price is:  164.56
# 2 : The current ask price is:  164.57
# 2 : The current ask price is:  164.58
# 2 : The current ask price is:  164.57
# 2 : The current ask price is:  164.58
# 2 : The current ask price is:  164.59
# 2 : The current ask price is:  164.6
# 2 : The current ask price is:  164.59
# 2 : The current ask price is:  164.58
# 2 : The current ask price is:  164.6
# 2 : The current ask price is:  164.59
# 2 : The current ask price is:  164.6
# 2 : The current ask price is:  164.59
# 2 : The current ask price is:  164.58
# 2 : The current ask price is:  164.57
# 2 : The current ask price is:  164.56
# 2 : The current ask price is:  164.55
# 2 : The current ask price is:  164.56
# 2 : The current ask price is:  164.55
# 2 : The current ask price is:  164.54
# 2 : The current ask price is:  164.53
# 2 : The current ask price is:  164.54
# 2 : The current ask price is:  164.53
# 2 : The current ask price is:  164.54
# 2 : The current ask price is:  164.55
# 2 : The current ask price is:  164.54
# 2 : The current ask price is:  164.55
# 2 : The current ask price is:  164.54
# 2 : The current ask price is:  164.53
# 2 : The current ask price is:  164.54
# 2 : The current ask price is:  164.53
# 2 : The current ask price is:  164.54
# 2 : The current ask price is:  164.53
# 2 : The current ask price is:  164.52
# 2 : The current ask price is:  164.53

# %%
app.data = []

eurusd_contract = Contract()
eurusd_contract.symbol = 'EUR'
eurusd_contract.secType = 'CASH'
eurusd_contract.exchange = 'IDEALPRO'
eurusd_contract.currency = 'USD'

#Request historical candles
app.reqHistoricalData(1, eurusd_contract, '', '2 D', '1 hour', 'BID', 0, 2, False, [])

# %%
app.data = []

es_contract = Contract()
es_contract.symbol = 'ES'
es_contract.secType = 'FUT'
es_contract.exchange = 'CME'
es_contract.currency = 'USD'
es_contract.lastTradeDateOrContractMonth = '20230616'
#es_contract.localSymbol = ""

#Request historical candles
app.reqHistoricalData(1, es_contract, '', '1 Y', '1 day', 'MIDPOINT', 0, 2, False, [])

# %%
app.data = []

eurzar_contract = Contract()
eurzar_contract.symbol = 'EUR'
eurzar_contract.secType = 'CASH'
eurzar_contract.exchange = 'IDEALPRO'
eurzar_contract.currency = 'ZAR'

#Request historical candles
app.reqHistoricalData(1, eurzar_contract, '', '1 Y', '1 day', 'MIDPOINT', 0, 2, False, [])

# %%
app.data
# Out:
# [['20220422', 4428.125, 4431.625, 4305.25, 4305.25],
#  ['20220425', 4296.125, 4335.75, 4252.875, 4335.75],
#  ['20220426', 4334.375, 4340.625, 4193.75, 4194.125],
#  ['20220427', 4196.625, 4268.875, 4195.875, 4239.625],
#  ['20220428', 4259.625, 4335.875, 4240.125, 4322.25],
#  ['20220429', 4288.25, 4312.125, 4176.125, 4176.125],
#  ['20220502', 4180.75, 4201.375, 4113.625, 4188.625],
#  ['20220503', 4189.125, 4228.125, 4180.25, 4213.125],
#  ['20220504', 4216.875, 4350.75, 4200.375, 4350.75],
#  ['20220505', 4355.0, 4357.875, 4176.75, 4209.375],
#  ['20220506', 4208.625, 4213.25, 4139.625, 4180.625],
#  ['20220509', 4148.5, 4156.125, 4040.875, 4059.125],
#  ['20220510', 4063.75, 4118.125, 4029.875, 4062.875],
#  ['20220511', 4055.875, 4103.125, 3991.875, 4001.0],
#  ['20220512', 4005.375, 4014.25, 3932.625, 3982.5],
#  ['20220513', 3985.0, 4081.125, 3983.0, 4073.875],
#  ['20220516', 4089.75, 4096.125, 4056.875, 4070.25],
#  ['20220517', 4066.375, 4141.75, 4066.125, 4136.375],
#  ['20220518', 4147.5, 4147.75, 3968.75, 3971.5],
#  ['20220519', 3969.125, 3986.125, 3916.25, 3953.375],
#  ['20220520', 3954.125, 3991.875, 3841.0, 3947.375],
#  ['20220523', 3966.625, 4024.75, 3966.25, 4024.75],
#  ['20220524', 3988.625, 4005.125, 3942.875, 4005.125],
#  ['20220525', 4009.875, 4045.875, 3984.75, 4028.125],
#  ['20220526', 4032.875, 4128.75, 4027.0, 4117.625],
#  ['20220527', 4106.625, 4214.125, 4106.25, 4214.125],
#  ['20220531', 4230.375, 4230.375, 4173.875, 4194.375],
#  ['20220601', 4194.375, 4211.125, 4142.625, 4163.375],
#  ['20220602', 4154.25, 4223.875, 4136.375, 4223.875],
#  ['20220603', 4237.0, 4244.375, 4166.875, 4170.0],
#  ['20220606', 4171.5, 4223.25, 4168.125, 4177.875],
#  ['20230321', 3986.5, 4043.125, 3981.625, 4039.125],
#  ['20230322', 4038.75, 4073.875, 3966.125, 3971.625],
#  ['20230323', 3972.75, 4039.375, 3948.625, 3987.875],
#  ['20230324', 3988.75, 4010.875, 3937.125, 4010.25],
#  ['20230327', 4008.0, 4034.125, 3997.375, 4014.875],
#  ['20230328', 4013.25, 4023.625, 3980.875, 4006.375],
#  ['20230329', 4006.5, 4061.375, 4006.125, 4057.875],
#  ['20230330', 4058.0, 4087.625, 4052.375, 4083.125],
#  ['20230331', 4081.0, 4142.375, 4078.125, 4139.375],
#  ['20230403', 4127.0, 4157.625, 4122.625, 4153.625],
#  ['20230404', 4152.5, 4171.625, 4115.125, 4132.875],
#  ['20230405', 4134.0, 4135.625, 4099.125, 4114.875],
#  ['20230406', 4113.75, 4135.125, 4096.625, 4130.875],
#  ['20230407', 4129.0, 4146.875, 4121.375, 4141.875],
#  ['20230410', 4139.0, 4142.875, 4098.875, 4139.125],
#  ['20230411', 4138.5, 4151.875, 4128.875, 4138.125],
#  ['20230412', 4137.5, 4177.5, 4113.625, 4117.125],
#  ['20230413', 4117.5, 4176.875, 4110.375, 4168.625],
#  ['20230414', 4168.75, 4188.875, 4138.125, 4171.875],
#  ['20230417', 4174.25, 4180.375, 4148.125, 4176.875],
#  ['20230418', 4177.0, 4198.375, 4164.625, 4178.875],
#  ['20230419', 4176.0, 4187.375, 4150.625, 4173.375],
#  ['20230420', 4172.25, 4173.375, 4136.875, 4153.875],
#  ['20230421', 4153.75, 4160.875, 4135.125, 4153.375]]

# %%
#Working with Pandas DataFrames
import pandas as pd
import numpy as np

df = pd.DataFrame(app.data, columns=['DateTime','Open', 'High', 'Low', 'Close'])

df.drop(['Open', 'High', 'Low'], axis=1, inplace=True)
df.rename(columns={'Close':'price'}, inplace=True)
df.rename(columns={'DateTime':'date'}, inplace=True)


#df = pd.DataFrame(app.data, columns=['DateTime','Close'])
df['10SMA'] = df['price'].rolling(10).mean()
df['30SMA'] = df['price'].rolling(30).mean()

#df['date'] = pd.to_datetime(df['date'],unit='s') 
df = df.set_index('date')
#df.to_csv('EURUSD_Hourly.csv')  
df.info()
df.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 245 entries, 20220422 to 20230421
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   price   245 non-null    float64
#  1   10SMA   236 non-null    float64
#  2   30SMA   216 non-null    float64
# dtypes: float64(3)
# memory usage: 7.7+ KB
#              price     10SMA        30SMA
# date
# 20230417  4176.875  4143.225  4051.183333
# 20230418  4178.875  4147.825  4056.241667
# 20230419  4173.375  4153.675  4060.833333
# 20230420  4153.875  4155.975  4067.454167
# 20230421  4153.375  4157.125  4075.458333

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 260 entries, 20220422 to 20230421
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   price   260 non-null    float64
#  1   10SMA   251 non-null    float64
#  2   30SMA   231 non-null    float64
# dtypes: float64(3)
# memory usage: 8.1+ KB

# %%
# %matplotlib inline
from pylab import mpl, plt

plt.style.use('seaborn')
mpl.rcParams['savefig.dpi'] = 300
mpl.rcParams['font.family'] = 'serif'

df.plot(title='blah', figsize=(10,6))
#plt.figure(figsize=(15, 6))
#plt.plot(df['Close'], label='EURZAR')
#plt.plot(df['10SMA'], label='SMA10')
#plt.plot(df['30SMA'], label='SMA30')
#plt.legend(loc='upper left', fontsize=15)
# Out:
# /tmp/ipykernel_61/7633009.py:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# <Axes: title={'center': 'blah'}, xlabel='date'>

# %%
df['position'] = np.where(df['10SMA'] > df['30SMA'], 1, -1)
df.dropna(inplace=True)

# %%
df.info()
df.tail(15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 110 entries, 2023-03-31 00:00:00 to 2023-04-21 20:00:00
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   price     110 non-null    float64
#  1   10SMA     110 non-null    float64
#  2   30SMA     110 non-null    float64
#  3   position  110 non-null    int64
# dtypes: float64(3), int64(1)
# memory usage: 4.3 KB
#                         price      10SMA      30SMA  position
# date
# 2023-04-19 20:00:00  19.91660  19.929785  19.938717        -1
# 2023-04-19 21:15:00  19.90280  19.926515  19.936800        -1
# 2023-04-20 00:00:00  19.94000  19.927780  19.936870        -1
# 2023-04-20 04:00:00  19.92600  19.927610  19.936640        -1
# 2023-04-20 08:00:00  19.87155  19.921655  19.933832        -1
# 2023-04-20 12:00:00  19.78385  19.906730  19.926105        -1
# 2023-04-20 16:00:00  19.78865  19.887775  19.920680        -1
# 2023-04-20 20:00:00  19.76810  19.867325  19.916050        -1
# 2023-04-20 21:15:00  19.76530  19.856420  19.912023        -1
# 2023-04-21 00:00:00  19.77600  19.843885  19.909653        -1
# 2023-04-21 04:00:00  19.83030  19.835255  19.907750        -1
# 2023-04-21 08:00:00  19.90255  19.835230  19.909733        -1
# 2023-04-21 12:00:00  19.84260  19.825490  19.907778        -1
# 2023-04-21 16:00:00  19.88360  19.821250  19.907790        -1
# 2023-04-21 20:00:00  19.85980  19.820075  19.903762        -1

# %%
df['position'].plot(x='date', 
                    ylim=[-1.1, 1.1],
                    title='Market Positioning',
                    figsize=(10,6))
# Out:
# <Axes: title={'center': 'Market Positioning'}, xlabel='date'>

# %%
df['returns'] = np.log(df['price'] / df['price'].shift(1))

# %%
df.tail(15)
# Out:
#              price      10SMA      30SMA  position   returns
# date
# 20230403  19.44955  19.623730  19.532230         1  0.008105
# 20230404  19.63785  19.589095  19.538728         1  0.009635
# 20230405  19.67405  19.571830  19.549833         1  0.001842
# 20230406  19.93495  19.605185  19.570867         1  0.013174
# 20230407  19.84620  19.635610  19.584665         1 -0.004462
# 20230410  20.10505  19.669205  19.603767         1  0.012958
# 20230411  20.06370  19.707500  19.625380         1 -0.002059
# 20230412  20.24300  19.768110  19.655700         1  0.008897
# 20230413  19.94410  19.819100  19.677507         1 -0.014876
# 20230414  19.88480  19.878325  19.697275         1 -0.002978
# 20230417  20.01245  19.934615  19.714730         1  0.006399
# 20230418  19.93215  19.964045  19.727872         1 -0.004021
# 20230419  19.93845  19.990485  19.738300         1  0.000316
# 20230420  19.78045  19.975035  19.742793         1 -0.007956
# 20230421  19.88925  19.979340  19.755730         1  0.005485

# %%
df['returns'].hist(bins=40, figsize=(10,6))
# Out:
# <Axes: >

# %%
df['strategy'] = df['position'].shift(1) * df['returns']

# %%
df.tail(20)
# Out:
#              price      10SMA        30SMA  position   returns  strategy
# date
# 20230327  4014.875  3983.6375  4026.300000        -1  0.001153 -0.001153
# 20230328  4006.375  3988.7500  4020.575000        -1 -0.002119  0.002119
# 20230329  4057.875  4001.9500  4015.929167        -1  0.012773 -0.012773
# 20230330  4083.125  4010.6250  4014.262500        -1  0.006203 -0.006203
# 20230331  4139.375  4029.7750  4014.816667         1  0.013682 -0.013682
# 20230403  4153.625  4046.4125  4016.166667         1  0.003437  0.003437
# 20230404  4132.875  4055.7875  4019.112500         1 -0.005008 -0.005008
# 20230405  4114.875  4070.1125  4021.429167         1 -0.004365 -0.004365
# 20230406  4130.875  4084.4125  4024.079167         1  0.003881  0.003881
# 20230407  4141.875  4097.5750  4028.466667         1  0.002659  0.002659
# 20230410  4139.125  4110.0000  4032.179167         1 -0.000664 -0.000664
# 20230411  4138.125  4123.1750  4036.579167         1 -0.000242 -0.000242
# 20230412  4117.125  4129.1000  4040.587500         1 -0.005088 -0.005088
# 20230413  4168.625  4137.6500  4045.558333         1  0.012431  0.012431
# 20230414  4171.875  4140.9000  4048.325000         1  0.000779  0.000779
# 20230417  4176.875  4143.2250  4051.183333         1  0.001198  0.001198
# 20230418  4178.875  4147.8250  4056.241667         1  0.000479  0.000479
# 20230419  4173.375  4153.6750  4060.833333         1 -0.001317 -0.001317
# 20230420  4153.875  4155.9750  4067.454167         1 -0.004683 -0.004683
# 20230421  4153.375  4157.1250  4075.458333         1 -0.000120 -0.000120

# %%
df[['returns','strategy']].sum()
# Out:
# returns    -0.003995
# strategy   -0.234263
# dtype: float64

# %%
df[['returns','strategy']].sum().apply(np.exp)
# Out:
# returns     0.996013
# strategy    0.791154
# dtype: float64

# %%
df[['returns','strategy']].cumsum().apply(np.exp).plot(figsize=(10,6))
# Out:
# <Axes: xlabel='date'>
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 1100 Connectivity between IBKR and Trader Workstation has been lost.
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:uscrypto
# ERROR -1 2103 Market data farm connection is broken:usfuture.nj
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:eufarm
# ERROR -1 2157 Sec-def data farm connection is broken:secdefeu
# ERROR -1 2105 HMDS data farm connection is broken:euhmds
# ERROR -1 2105 HMDS data farm connection is broken:ushmds.nj
# ERROR -1 2105 HMDS data farm connection is broken:cashhmds
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefeu
# ERROR -1 2106 HMDS data farm connection is OK:cashhmds
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2106 HMDS data farm connection is OK:ushmds.nj
# ERROR -1 2104 Market data farm connection is OK:usfuture.nj
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:eufarm
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:uscrypto
# ERROR -1 1102 Connectivity between IBKR and Trader Workstation has been restored - data maintained. All data farms are connected: cashfarm; uscrypto; usfuture.nj; usfuture; usfarm.nj; eufarm; usfarm; euhmds; ushmds.nj; cashhmds; ushmds; secdefeu.
# ERROR -1 1100 Connectivity between IBKR and Trader Workstation has been lost.
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:uscrypto
# ERROR -1 2103 Market data farm connection is broken:usfuture.nj
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:eufarm
# ERROR -1 2157 Sec-def data farm connection is broken:secdefeu
# ERROR -1 2105 HMDS data farm connection is broken:euhmds
# ERROR -1 2105 HMDS data farm connection is broken:ushmds.nj
# ERROR -1 2105 HMDS data farm connection is broken:cashhmds
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2106 HMDS data farm connection is OK:cashhmds
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefeu
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:usfuture.nj
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2106 HMDS data farm connection is OK:ushmds.nj
# ERROR -1 2104 Market data farm connection is OK:eufarm
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:uscrypto
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 1102 Connectivity between IBKR and Trader Workstation has been restored - data maintained. All data farms are connected: cashfarm; uscrypto; usfuture.nj; usfuture; usfarm.nj; eufarm; usfarm; euhmds; ushmds.nj; cashhmds; ushmds; secdefeu.
# ERROR -1 1100 Connectivity between IBKR and Trader Workstation has been lost.
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:uscrypto
# ERROR -1 2103 Market data farm connection is broken:usfuture.nj
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:eufarm
# ERROR -1 2157 Sec-def data farm connection is broken:secdefeu
# ERROR -1 2105 HMDS data farm connection is broken:euhmds
# ERROR -1 2105 HMDS data farm connection is broken:ushmds.nj
# ERROR -1 2105 HMDS data farm connection is broken:cashhmds
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2106 HMDS data farm connection is OK:cashhmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefeu
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:usfuture.nj
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2106 HMDS data farm connection is OK:ushmds.nj
# ERROR -1 2104 Market data farm connection is OK:eufarm
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:uscrypto
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 1102 Connectivity between IBKR and Trader Workstation has been restored - data maintained. All data farms are connected: cashfarm; uscrypto; usfuture.nj; usfuture; usfarm.nj; eufarm; usfarm; euhmds; ushmds.nj; cashhmds; ushmds; secdefeu.
# ERROR -1 1100 Connectivity between IBKR and Trader Workstation has been lost.
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:uscrypto
# ERROR -1 2103 Market data farm connection is broken:usfuture.nj
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:eufarm
# ERROR -1 2157 Sec-def data farm connection is broken:secdefeu
# ERROR -1 2105 HMDS data farm connection is broken:euhmds
# ERROR -1 2105 HMDS data farm connection is broken:ushmds.nj
# ERROR -1 2105 HMDS data farm connection is broken:cashhmds
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefeu
# ERROR -1 2106 HMDS data farm connection is OK:cashhmds
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2106 HMDS data farm connection is OK:ushmds.nj
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2104 Market data farm connection is OK:usfuture.nj
# ERROR -1 2104 Market data farm connection is OK:eufarm
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:uscrypto
# ERROR -1 1102 Connectivity between IBKR and Trader Workstation has been restored - data maintained. All data farms are connected: cashfarm; uscrypto; usfuture.nj; usfuture; usfarm.nj; eufarm; usfarm; euhmds; ushmds.nj; cashhmds; ushmds; secdefeu.
# ERROR -1 1100 Connectivity between IBKR and Trader Workstation has been lost.
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:uscrypto
# ERROR -1 2103 Market data farm connection is broken:usfuture.nj
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:eufarm
# ERROR -1 2157 Sec-def data farm connection is broken:secdefeu
# ERROR -1 2105 HMDS data farm connection is broken:euhmds
# ERROR -1 2105 HMDS data farm connection is broken:ushmds.nj
# ERROR -1 2105 HMDS data farm connection is broken:cashhmds
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2106 HMDS data farm connection is OK:cashhmds
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefeu
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2106 HMDS data farm connection is OK:ushmds.nj
# ERROR -1 2104 Market data farm connection is OK:usfuture.nj
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:eufarm
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:uscrypto
# ERROR -1 1102 Connectivity between IBKR and Trader Workstation has been restored - data maintained. All data farms are connected: cashfarm; uscrypto; usfuture.nj; usfuture; usfarm.nj; eufarm; usfarm; euhmds; ushmds.nj; cashhmds; ushmds; secdefeu.
# ERROR -1 1100 Connectivity between IBKR and Trader Workstation has been lost.
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:uscrypto
# ERROR -1 2103 Market data farm connection is broken:usfuture.nj
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:eufarm
# ERROR -1 2157 Sec-def data farm connection is broken:secdefeu
# ERROR -1 2105 HMDS data farm connection is broken:euhmds
# ERROR -1 2105 HMDS data farm connection is broken:ushmds.nj
# ERROR -1 2105 HMDS data farm connection is broken:cashhmds
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2106 HMDS data farm connection is OK:cashhmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefeu
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:usfuture.nj
# ERROR -1 2104 Market data farm connection is OK:eufarm
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2106 HMDS data farm connection is OK:ushmds.nj
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:uscrypto
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 1102 Connectivity between IBKR and Trader Workstation has been restored - data maintained. All data farms are connected: cashfarm; uscrypto; usfuture.nj; usfuture; usfarm.nj; eufarm; usfarm; euhmds; ushmds.nj; cashhmds; ushmds; secdefeu.
# ERROR -1 1100 Connectivity between IBKR and Trader Workstation has been lost.
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:uscrypto
# ERROR -1 2103 Market data farm connection is broken:usfuture.nj
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:eufarm
# ERROR -1 2157 Sec-def data farm connection is broken:secdefeu
# ERROR -1 2105 HMDS data farm connection is broken:euhmds
# ERROR -1 2105 HMDS data farm connection is broken:ushmds.nj
# ERROR -1 2105 HMDS data farm connection is broken:cashhmds
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefeu
# ERROR -1 2106 HMDS data farm connection is OK:cashhmds
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:usfuture.nj
# ERROR -1 2106 HMDS data farm connection is OK:ushmds.nj
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:eufarm
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:uscrypto
# ERROR -1 1102 Connectivity between IBKR and Trader Workstation has been restored - data maintained. All data farms are connected: cashfarm; uscrypto; usfuture.nj; usfuture; usfarm.nj; eufarm; usfarm; euhmds; ushmds.nj; cashhmds; ushmds; secdefeu.
# ERROR -1 1100 Connectivity between IBKR and Trader Workstation has been lost.
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:uscrypto
# ERROR -1 2103 Market data farm connection is broken:usfuture.nj
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:eufarm
# ERROR -1 2157 Sec-def data farm connection is broken:secdefeu
# ERROR -1 2105 HMDS data farm connection is broken:euhmds
# ERROR -1 2105 HMDS data farm connection is broken:ushmds.nj
# ERROR -1 2105 HMDS data farm connection is broken:cashhmds
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefeu
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2106 HMDS data farm connection is OK:cashhmds
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2106 HMDS data farm connection is OK:ushmds.nj
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2104 Market data farm connection is OK:usfuture.nj
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:eufarm
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:uscrypto
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 1102 Connectivity between IBKR and Trader Workstation has been restored - data maintained. All data farms are connected: cashfarm; uscrypto; usfuture.nj; usfuture; usfarm.nj; eufarm; usfarm; euhmds; ushmds.nj; cashhmds; ushmds; secdefeu.
# ERROR -1 2105 HMDS data farm connection is broken:cashhmds
# ERROR -1 2157 Sec-def data farm connection is broken:secdefeu
# ERROR -1 2105 HMDS data farm connection is broken:euhmds
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2105 HMDS data farm connection is broken:ushmds.nj
# ERROR -1 2103 Market data farm connection is broken:usfuture.nj
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2103 Market data farm connection is broken:eufarm
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:uscrypto
# ERROR -1 2158 Sec-def data farm connection is OK:secdefeu
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2106 HMDS data farm connection is OK:cashhmds
# ERROR -1 1100 Connectivity between IBKR and Trader Workstation has been lost.
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:eufarm
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:uscrypto
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2106 HMDS data farm connection is OK:ushmds.nj
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:uscrypto
# ERROR -1 2103 Market data farm connection is broken:usfuture.nj
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:eufarm
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2157 Sec-def data farm connection is broken:secdefeu
# ERROR -1 2105 HMDS data farm connection is broken:euhmds
# ERROR -1 2105 HMDS data farm connection is broken:ushmds.nj
# ERROR -1 2105 HMDS data farm connection is broken:cashhmds
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefeu
# ERROR -1 2106 HMDS data farm connection is OK:cashhmds
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2106 HMDS data farm connection is OK:ushmds.nj
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2104 Market data farm connection is OK:usfuture.nj
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:eufarm
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:uscrypto
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 1102 Connectivity between IBKR and Trader Workstation has been restored - data maintained. All data farms are connected: cashfarm; uscrypto; usfuture.nj; usfuture; usfarm.nj; eufarm; usfarm; euhmds; ushmds.nj; cashhmds; ushmds; secdefeu.
# ERROR -1 1100 Connectivity between IBKR and Trader Workstation has been lost.
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:uscrypto
# ERROR -1 2103 Market data farm connection is broken:usfuture.nj
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:eufarm
# ERROR -1 2157 Sec-def data farm connection is broken:secdefeu
# ERROR -1 2105 HMDS data farm connection is broken:euhmds
# ERROR -1 2105 HMDS data farm connection is broken:ushmds.nj
# ERROR -1 2105 HMDS data farm connection is broken:cashhmds
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2106 HMDS data farm connection is OK:cashhmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefeu
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:usfuture.nj
# ERROR -1 2106 HMDS data farm connection is OK:ushmds.nj
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:eufarm
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:uscrypto
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 1102 Connectivity between IBKR and Trader Workstation has been restored - data maintained. All data farms are connected: cashfarm; uscrypto; usfuture.nj; usfuture; usfarm.nj; eufarm; usfarm; euhmds; ushmds.nj; cashhmds; ushmds; secdefeu.
# ERROR -1 1100 Connectivity between IBKR and Trader Workstation has been lost.
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:uscrypto
# ERROR -1 2103 Market data farm connection is broken:usfuture.nj
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:eufarm
# ERROR -1 2157 Sec-def data farm connection is broken:secdefeu
# ERROR -1 2105 HMDS data farm connection is broken:euhmds
# ERROR -1 2105 HMDS data farm connection is broken:ushmds.nj
# ERROR -1 2105 HMDS data farm connection is broken:cashhmds
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2106 HMDS data farm connection is OK:cashhmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefeu
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2106 HMDS data farm connection is OK:ushmds.nj
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2104 Market data farm connection is OK:usfuture.nj
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:eufarm
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:uscrypto
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 1102 Connectivity between IBKR and Trader Workstation has been restored - data maintained. All data farms are connected: cashfarm; uscrypto; usfuture.nj; usfuture; usfarm.nj; eufarm; usfarm; euhmds; ushmds.nj; cashhmds; ushmds; secdefeu.
# ERROR -1 1100 Connectivity between IBKR and Trader Workstation has been lost.
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:uscrypto
# ERROR -1 2103 Market data farm connection is broken:usfuture.nj
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:eufarm
# ERROR -1 2157 Sec-def data farm connection is broken:secdefeu
# ERROR -1 2105 HMDS data farm connection is broken:euhmds
# ERROR -1 2105 HMDS data farm connection is broken:ushmds.nj
# ERROR -1 2105 HMDS data farm connection is broken:cashhmds
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2106 HMDS data farm connection is OK:cashhmds
# ERROR -1 2158 Sec-def data farm connection is OK:secdefeu
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:usfuture.nj
# ERROR -1 2104 Market data farm connection is OK:eufarm
# ERROR -1 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:uscrypto
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2106 HMDS data farm connection is OK:ushmds.nj
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 1102 Connectivity between IBKR and Trader Workstation has been restored - data maintained. All data farms are connected: cashfarm; uscrypto; usfuture.nj; usfuture; usfarm.nj; eufarm; usfarm; euhmds; ushmds.nj; cashhmds; ushmds; secdefeu.
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 1100 Connectivity between IBKR and Trader Workstation has been lost.
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2157 Sec-def data farm connection is broken:secdefeu
# ERROR -1 2103 Market data farm connection is broken:usfuture.nj
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:uscrypto
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:eufarm
# ERROR -1 2105 HMDS data farm connection is broken:euhmds
# ERROR -1 2106 HMDS data farm connection is OK:euhmds
# ERROR -1 2104 Market data farm connection is OK:eufarm
# ERROR -1 2158 Sec-def data farm connection is OK:secdefeu
# ERROR -1 2104 Market data farm connection is OK:cashfarm
# ERROR -1 2104 Market data farm connection is OK:usfuture.nj
# ERROR -1 2104 Market data farm connection is OK:usfarm
# ERROR -1 2104 Market data farm connection is OK:usfuture
# ERROR -1 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 2104 Market data farm connection is OK:uscrypto
# ERROR -1 1102 Connectivity between IBKR and Trader Workstation has been restored - data maintained. All data farms are connected: cashfarm; uscrypto; usfuture.nj; usfuture; usfarm.nj; eufarm; usfarm; euhmds; ushmds.nj; cashhmds; ushmds; secdefeu.
# ERROR -1 1100 Connectivity between IBKR and Trader Workstation has been lost.
# ERROR -1 2103 Market data farm connection is broken:usfarm
# ERROR -1 2105 HMDS data farm connection is broken:cashhmds
# ERROR -1 2105 HMDS data farm connection is broken:ushmds
# ERROR -1 2103 Market data farm connection is broken:cashfarm
# ERROR -1 2103 Market data farm connection is broken:uscrypto
# ERROR -1 2103 Market data farm connection is broken:usfuture.nj
# ERROR -1 2103 Market data farm connection is broken:usfuture
# ERROR -1 2103 Market data farm connection is broken:usfarm.nj
# ERROR -1 2103 Market data farm connection is broken:eufarm
# ERROR -1 2157 Sec-def data farm connection is broken:secdefeu
# ERROR -1 2105 HMDS data farm connection is broken:euhmds
# ERROR -1 2105 HMDS data farm connection is broken:ushmds.nj

# %%
app.disconnect()
